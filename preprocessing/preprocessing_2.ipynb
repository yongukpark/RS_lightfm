# %% [markdown]
# ### TTS

# %%
import pandas as pd

data = pd.read_csv("./output/output(LE).csv")

# %%
data
# Out:
#         MESURE_AGE_CO  SEXDSTN_FLAG_CD  MESURE_IEM_001_VALUE  \
# 0                  64                1                 166.6
# 1                  60                1                 174.2
# 2                  65                1                 163.4
# 3                  35                1                 178.2
# 4                  75                1                 168.0
# ...               ...              ...                   ...
# 747727             15                2                 163.1
# 747728             14                1                 183.3
# 747729             15                1                 180.3
# 747730             15                2                 155.0
# 747731             14                1                 176.0
#
#         MESURE_IEM_002_VALUE  MESURE_IEM_003_VALUE  MESURE_IEM_005_VALUE  \
# 0                       79.3                  36.3                  85.0
# 1                       74.1                  26.8                  94.0
# ...

# %%
import numpy as np
data['start'] = data['start'].apply(lambda x: [int(i) for i in x.strip('[]').split()])
data['main'] = data['main'].apply(lambda x: [int(i) for i in x.strip('[]').split()])
data['end'] = data['end'].apply(lambda x: [int(i) for i in x.strip('[]').split()])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 2
#       1 import numpy as np
# ----> 2 data['start'] = data['start'].apply(lambda x: [int(i) for i in x.strip('[]').split()])
#       3 data['main'] = data['main'].apply(lambda x: [int(i) for i in x.strip('[]').split()])
#       4 data['end'] = data['end'].apply(lambda x: [int(i) for i in x.strip('[]').split()])
#
# File ~/anaconda3/envs/study/lib/python3.11/site-packages/pandas/core/series.py:4630, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4520 def apply(
#    4521     self,
#    4522     func: AggFuncType,
#    (...)
#    4525     **kwargs,
#    4526 ) -> DataFrame | Series:
#    4527     """
#    4528     Invoke function on values of Series.
#    4529
#    (...)
#    4628     dtype: float64
#    4629     """
# ...

# %%
data.to_csv('output/output(LE).csv', index=False)
